# %%
import pytensor
import torch
import pandas as pd
import numpy as np
print(torch.__version__)
# Out:
# 2.5.1+cpu

# %%
#operator in tensor
#addition
tensor=torch.tensor([1,2,3])
tensor+10
# Out:
# tensor([11, 12, 13])

# %%
#multiplication
tensor*10
# Out:
# tensor([10, 20, 30])

# %%
#matrix multiplication
m1=torch.tensor([[[1,2,3],[4,5,6],[6,7,8]]])
m1

# %%
m2=torch.tensor([[[6,7,8],[4,5,6],[1,2,3]]])
m2

# %%
m1*m2

# %%
#actual matrix multiplication
torch.matmul(m1,m2)
